# %%
import json
import re

# %%
f = open('./data/fbdata.json', "r")

# %%
fb_corpus = json.load(f)

# %%
f = open('./data/people.popular.2', 'rb')
pop_data = f.readlines()

# %%
# create a corpus of the top N person in the freebase
top_n = 100
top_list = [unicode(re.split(r'\t+', pop)[0], 'utf8') for pop in pop_data[0:top_n*10]]
used_names = set()
top_fb_corpus = {}

for key, val in fb_corpus.iteritems():
    if val.get(u'name') in top_list and val.get(u'name') not in used_names:
        top_fb_corpus[key] = val
        used_names.add(val.get(u'name'))
    if len(top_fb_corpus) >= top_n:
        break
print len(top_fb_corpus)
# Out:
# 100

# %% [markdown]
# Analysis the top N people a little bit

# %%
# get all the fileds
field_set = set()
field_count = {}
field_modality = {}
for key, value in top_fb_corpus.iteritems():
    for field, content in value.iteritems():
        # update count and update modality
        moda = field_modality.get(field, set())
        if type(content) is list:
            cnt = field_count.get(field, 0) + len(content)
            for c in content:
                moda.add(c)
        else:
            cnt = field_count.get(field, 0) + 1
            moda.add(c)  
        # save
        field_set.add(field)  
        field_count[field] = cnt
        field_modality[field] = moda
print str(len(field_set)) + ' unique fileds'
print ''
print [(k, v/float(100)) for k, v in field_count.iteritems()]
print ''
print [(k, len(v)) for k, v in field_modality.iteritems()]
# Out:
# 11 unique fileds
#
# [(u'birthplace', 0.57), (u'education', 0.49), (u'name', 1.0), (u'degree', 0.0), (u'gender', 0.78), (u'profession', 2.1), (u'birthday', 0.66), (u'deathplace', 0.23), (u'nationality', 0.6), (u'spouse', 1.06), (u'Types', 7.83)]
#
# [(u'birthplace', 53), (u'education', 44), (u'name', 79), (u'degree', 0), (u'gender', 2), (u'profession', 61), (u'birthday', 66), (u'deathplace', 21), (u'nationality', 17), (u'spouse', 82), (u'Types', 91)]

# %% [markdown]
# save the top_corpus

# %%
json.dump(top_fb_corpus, open('./data/top100.json', 'w'))

# %%
[list(v) for k, v in field_modality.iteritems()]
# Out:
# [[u'M\xf6drath',
#   u'Paris',
#   u'Philadelphia',
#   u'Newark',
#   u'Winnipeg',
#   u'San Francisco',
#   u'Beaconsfield',
#   u'Santa Cruz de Tenerife',
#   u'Aylesbury',
#   u'Riverside',
#   u'Airdrie',
#   u'Ankara',
#   u'Honfleur',
#   u'New York City',
#   u'Moscow',
#   u'Buenos Aires',
#   u'Gronau',
#   u'York',
#   u'Los Angeles',
#   u'Berkeley',
#   u'Oxford',
#   u'S\xe8te',
#   u'Gothenburg',
#   u'Jacksonville',
#   u'Southport',
#   u'Hammersmith',
#   u'Shubra',
#   u'Cheltenham',
#   u'Wichita',
#   u'Dublin',
#   u'Kansas City',
#   u'Ottawa',
#   u'Herminie',
#   u'Le Roncole',
#   u'Tucson',
#   u'Greco',
#   u'Detroit',
#   u'Glendale',
#   u"Hell's Kitchen",
#   u'Honesdale',
#   u'Marseille',
#   u'Houston',
#   u'Staten Island',
#   u'McComb',
#   u'Savannah',
#   u'Nelahozeves',
#   u'Fort Monroe',
#   u'Hetton-le-Hole',
#   u'New Orleans',
#   u'Birmingham',
#   u'Runcorn',
#   u'Champaign',
#   u'Jarocin'],
#  [u'Royal College of Music',
#   u'Leeds Beckett University',
#   u'University of Notre Dame',
#   u'School of Visual Arts',
#   u'Guildhall School of Music and Drama',
#   u'Music Academy of the West',
#   u'Alief Elsik High School',
#   u'Gar-Field Senior High School',
#   u'Schola Cantorum de Paris',
#   u'Parker Elementary School',
#   u'Georgia State University',
#   u'Moscow Conservatory',
#   u'Juilliard School',
#   u'Arizona State University',
#   u'California Institute of the Arts',
#   u'University of Southern California',
#   u'High School for the Performing and Visual Arts',
#   u'University College London',
#   u'Columbia University',
#   u'University of Bonn',
#   u'Bell High School',
#   u'Hertford College, Oxford',
#   u'Banneker High School',
#   u"St Peter's School, York",
#   u'Hochschule f\xfcr Musik und Tanz K\xf6ln',
#   u'University of Manchester',
#   u'Art Students League of New York',
#   u'The Thacher School',
#   u'Scuola Tecnica Commerciale Maria Ausiliatrice',
#   u'Tisch School of the Arts',
#   u'Convent of the Sacred Heart',
#   u'Mannes College The New School for Music',
#   u'McGill University',
#   u'Professional Performing Arts School',
#   u'Jesus College, Oxford',
#   u"Pate's Grammar School",
#   u"St. Mary's Elementary School",
#   u'Lund University',
#   u'John Hampden Grammar School',
#   u'University of North Carolina at Greensboro',
#   u'Ulster University',
#   u'Conservatoire de Paris',
#   u'Oak Park and River Forest High School',
#   u'Berlin University of the Arts'],
#  [u'Lena Kallersj\xf6',
#   u'An\xedbal Troilo',
#   u'Gloria Gaynor',
#   u'book.author',
#   u'Ir\xe8ne Mauriat',
#   u'film.actor',
#   u'Philadelphia',
#   u'Anton\xedn Dvo\u0159\xe1k',
#   u'Santa Cruz de Tenerife',
#   u'Glendale',
#   u'Deborah Sale Butler',
#   u'Winnipeg',
#   u'Detroit',
#   u'music.producer',
#   u'tv.tv_writer',
#   u'film.film_subject',
#   u'Mark Isham',
#   u'Aylesbury',
#   u'Riverside',
#   u'Airdrie',
#   u'Ankara',
#   u'Jane Hansen',
#   u'Gustav Holst',
#   u'Artis Mills',
#   u'Jacksonville',
#   u'music.musical_group',
#   u'Margherita Barezzi',
#   u'Wichita',
#   u'Swizz Beatz',
#   u'Gronau',
#   u'broadcast.artist',
#   u'film.person_or_entity_appearing_in_film',
#   u'tv.tv_actor',
#   u'organization.organization_member',
#   u'Berkeley',
#   u'Birmingham',
#   u'Chris Brown',
#   u'people.measured_person',
#   u'Jacqueline du Pr\xe9',
#   u'Southport',
#   u'Hammersmith',
#   u'Marie Laure Emile Truffot',
#   u'music.artist',
#   u'american_football.football_coach',
#   u'Ottawa',
#   u'Herminie',
#   u'Sophie Howard',
#   u'John Barry',
#   u'Jean Sobieski',
#   u'people.person',
#   u'award.award_nominee',
#   u'award.award_winner',
#   u'Erik Satie',
#   u'Cedric Gibbons',
#   u'music.group_member',
#   u'Honesdale',
#   u'S\xe8te',
#   u'Lyn Pratchett',
#   u'Staten Island',
#   u'Walter Legge',
#   u'Deanna Jones',
#   u'Emmylou Harris',
#   u'Savannah',
#   u'David Newman',
#   u'Steve Earle',
#   u'sports.pro_athlete',
#   u'Tucson',
#   u'Claudia Mori',
#   u'Hetton-le-Hole',
#   u'user.narphorium.people.topic',
#   u'New Orleans',
#   u'Doris Andreae',
#   u'Bo Diddley',
#   u'Runcorn',
#   u'Champaign',
#   u'New York City',
#   u'Beyonc\xe9 Knowles',
#   u'music.lyricist',
#   u'Moscow'],
#  [],
#  [u'Male', u'Female'],
#  [u'Film Editor',
#   u'Baseball player',
#   u'Trumpeter',
#   u'Photographer',
#   u'Rocket scientist',
#   u'Writer',
#   u'Firefighter',
#   u'Actor',
#   u'Violinist',
#   u'Music pedagogue',
#   u'Cellist',
#   u'Poet',
#   u'Pianist',
#   u'Jazz Pianist',
#   u'Pornographic film actor',
#   u'Orchestrator',
#   u'Conductor',
#   u'Entrepreneur',
#   u'American Football coach',
#   u'Theatrical producer',
#   u'Music artist',
#   u'Musician',
#   u'Fashion designer',
#   u'Film Score Composer',
#   u'Organist',
#   u'Opera composer',
#   u'Philanthropist',
#   u'Bassist',
#   u'Singer-songwriter',
#   u'Set Decorator',
#   u'Production designer',
#   u'Screenwriter',
#   u'Painter',
#   u'Singer',
#   u'Film director',
#   u'Politician',
#   u'Television producer',
#   u'Film Producer',
#   u'Athlete',
#   u'Rapper',
#   u'Presenter',
#   u'Author',
#   u'Music Video Director',
#   u'Voice acting',
#   u'Record producer',
#   u'Social activist',
#   u'Guitarist',
#   u'Playwright',
#   u'Bandleader',
#   u'Salesman',
#   u'Video Artist',
#   u'Lyricist',
#   u'Teacher',
#   u'Songwriter',
#   u'Businessperson',
#   u'Comedian',
#   u'Composer',
#   u'Music Arranger',
#   u'Novelist',
#   u'American football player',
#   u'Film Art Director'],
#  [u'951-06-09',
#   u'924-11-12',
#   u'893-03-23',
#   u'911-12-15',
#   u'760',
#   u'947-04-02',
#   u'948-04-28',
#   u'858-01-17',
#   u'961-03-05',
#   u'928-12-30',
#   u'877-01-22',
#   u'938-01-25',
#   u'928-05-12',
#   u'946-07-15',
#   u'946-05-17',
#   u'925-03-04',
#   u'939-04-09',
#   u'954',
#   u'911-09-24',
#   u'962-11-01',
#   u'970',
#   u'945-01-26',
#   u'977-09-11',
#   u'835-10-09',
#   u'949-09-07',
#   u'962-07-29',
#   u'944-08-18',
#   u'913',
#   u'841-09-08',
#   u'931-07-21',
#   u'813-10-10',
#   u'933-11-03',
#   u'992',
#   u'982-08-31',
#   u'934-06-09',
#   u'986-03-28',
#   u'874-09-21',
#   u'928-08-22',
#   u'872-01-06',
#   u'812-01-11',
#   u'981-09-04',
#   u'991-12-15',
#   u'954-03-11',
#   u'767-06-19',
#   u'970-11-08',
#   u'955-01-17',
#   u'951-09-07',
#   u'964-11-10',
#   u'958-05-01',
#   u'967-10-10',
#   u'887-09-23',
#   u'933-01-17',
#   u'961',
#   u'938-01-06',
#   u'941-11-21',
#   u'957-07-09',
#   u'973-04-03',
#   u'921-10-22',
#   u'981-01-25',
#   u'941',
#   u'914-07-11',
#   u'866-05-17',
#   u'912-09-27',
#   u'945-04-25',
#   u'915-12-09',
#   u'956-08-18'],
#  [u'Mount Holly',
#   u'Town of Oyster Bay',
#   u'Cincinnati',
#   u'Schruns',
#   u'Paris',
#   u'New York City',
#   u'Moscow',
#   u'Saint-G\xe9ly-du-Fesc',
#   u'Buenos Aires',
#   u'Algiers',
#   u'Arcueil',
#   u'Prague',
#   u'Milan',
#   u'Archer',
#   u'K\xfcrten',
#   u'Los Angeles',
#   u'Danville',
#   u'London',
#   u'Hollywood',
#   u'Perpignan',
#   u'Riverside'],
#  [u'Canada',
#   u'Turkey',
#   u'England',
#   u'Scotland',
#   u'Poland',
#   u'United States of America',
#   u'Republic of Ireland',
#   u'France',
#   u'United Kingdom',
#   u'Sweden',
#   u'Germany',
#   u'Italy',
#   u'Argentina',
#   u'Kingdom of Bohemia',
#   u'Russia',
#   u'Spain',
#   u'Kingdom of Italy'],
#  [u'Lena Kallersj\xf6',
#   u'An\xedbal Troilo',
#   u'Gloria Gaynor',
#   u'Carol-Ann Hunter',
#   u'Paul Kennerley',
#   u'Burt Bacharach',
#   u'Margherita Barezzi',
#   u'Carole Bayer Sager',
#   u'Mary Bauermeister',
#   u'John Barry',
#   u'Karlheinz Stockhausen',
#   u'Paul Mauriat',
#   u'Deborah Sale Butler',
#   u'Brian Ahern',
#   u'Alicia Keys',
#   u'Agnetha F\xe4ltskog',
#   u'Anton\xedn Dvo\u0159\xe1k',
#   u'Elisabeth Schwarzkopf',
#   u'Krystyna Newman',
#   u'John Butler',
#   u'Jane Hansen',
#   u'Gustav Holst',
#   u'Donna Isham',
#   u'Sandra Jean Henderson',
#   u'Allison Moorer',
#   u'Bj\xf6rn Ulvaeus',
#   u'Daniel Barenboim',
#   u'Linwood Simon',
#   u'Swizz Beatz',
#   u'Ir\xe8ne Mauriat',
#   u'Dalida',
#   u'Ron Jones',
#   u'Maria Teresa Ensenat',
#   u'Etta James',
#   u'Doris Andreae',
#   u'Rosanna Arquette',
#   u'Lucien Morisse',
#   u'Giuseppe Verdi',
#   u'Paula Stewart',
#   u'Jane Birkin',
#   u'Sylvia Paiz',
#   u'Camille Saint-Sa\xebns',
#   u'Ethel Smith',
#   u'Emily Isobel Harrison',
#   u'Suzanne Valadon',
#   u'Angie Dickinson',
#   u'Cedric Gibbons',
#   u'Bo Diddley',
#   u'Sophie Howard',
#   u'Jean Sobieski',
#   u'Kay Reynolds',
#   u'Chris Brown',
#   u'Hazel Brooks',
#   u'Erik Satie',
#   u'Ida Dudui Kalacci',
#   u'James Newton Howard',
#   u'Tom Slocum',
#   u'Lou-Anne Gill',
#   u'Barbara Pickard',
#   u'Lyn Pratchett',
#   u'Bob Brown',
#   u'Jane Sidey',
#   u'Mark Isham',
#   u'Dolores del R\xedo',
#   u'Walter Legge',
#   u'Deanna Jones',
#   u'Emmylou Harris',
#   u'Terry Pratchett',
#   u'David Newman',
#   u'Steve Earle',
#   u'Artis Mills',
#   u'Claudia Mori',
#   u'Giuseppina Strepponi',
#   u'Louise Woolingham',
#   u'Adriano Celentano',
#   u'Jacqueline du Pr\xe9',
#   u'Laurie Barry',
#   u'Cynthia Dunn',
#   u'Beyonc\xe9 Knowles',
#   u'Jay-Z',
#   u'Marie Laure Emile Truffot',
#   u'Anna \u010cerm\xe1kov\xe1'],
#  [u'book.author',
#   u'film.writer',
#   u'tv.tv_program_guest',
#   u'film.film_story_contributor',
#   u'media_common.dedicatee',
#   u'film.editor',
#   u'symbols.namesake',
#   u'music.music_video_director',
#   u'symbols.name_source',
#   u'visual_art.visual_artist',
#   u'film.film_production_designer',
#   u'theater.theater_producer',
#   u'film.director',
#   u'music.artist',
#   u'music.featured_artist',
#   u'award.award_nominee',
#   u'music.group_member',
#   u'music.guitarist',
#   u'people.deceased_person',
#   u'olympics.olympic_athlete',
#   u'internet.social_network_user',
#   u'film.producer',
#   u'theater.theatrical_lyricist',
#   u'theater.theater_actor',
#   u'business.product_endorser',
#   u'user.narphorium.people.topic',
#   u'celebrities.celebrity',
#   u'medicine.notable_person_with_medical_condition',
#   u'business.board_member',
#   u'music.songwriter',
#   u'organization.organization_founder',
#   u'theater.theatrical_composer',
#   u'film.film_set_designer',
#   u'music.producer',
#   u'baseball.baseball_player',
#   u'film.music_contributor',
#   u'architecture.architectural_structure_owner',
#   u'film.person_or_entity_appearing_in_film',
#   u'user.narphorium.people.nndb_person',
#   u'book.book_subject',
#   u'music.musical_group',
#   u'organization.organization_member',
#   u'award.ranked_item',
#   u'theater.theatrical_orchestrator',
#   u'tv.tv_personality',
#   u'people.person',
#   u'fictional_universe.person_in_fiction',
#   u'user.alexbl.honorary_title.topic',
#   u'internet.blogger',
#   u'film.actor',
#   u'award.award_winner',
#   u'sports.sports_team_coach',
#   u'award.hall_of_fame_inductee',
#   u'user.ngerakines.social_software.twitter_user',
#   u'influence.influence_node',
#   u'user.alust.default_domain.processed_with_review_queue',
#   u'film.cinematographer',
#   u'user.robert.performance.performer',
#   u'tv.tv_actor',
#   u'film.film_art_director',
#   u'music.composer',
#   u'opera.librettist',
#   u'broadcast.artist',
#   u'american_football.football_coach',
#   u'user.alexbl.honorary_title.titled_person',
#   u'music.music_video_performer',
#   u'film.film_crewmember',
#   u'sports.pro_athlete',
#   u'soccer.football_player',
#   u'award.long_list_nominee',
#   u'fictional_universe.fictional_character_creator',
#   u'user.wf.shape_note_singing.singer',
#   u'american_football.football_player',
#   u'media_common.dedicator',
#   u'user.viral.default_domain.music_publisher',
#   u'tv.tv_writer',
#   u'film.film_subject',
#   u'tv.tv_program_creator',
#   u'sports.sports_award_winner',
#   u'user.maxim75.default_domain.dbpedia_import',
#   u'tv.tv_producer',
#   u'cricket.cricket_player',
#   u'people.measured_person',
#   u'common.webpage',
#   u'user.robert.default_domain.famous_czech',
#   u'government.politician',
#   u'user.xena.default_domain.soprano',
#   u'music.opera_singer',
#   u'royalty.chivalric_order_member',
#   u'user.xena.default_domain.contralto',
#   u'music.lyricist']]

# %%
u'Anton\xedn Dvo\u0159\xe1k'.encode('utf8')
# Out:
# 'Anton\xc3\xadn Dvo\xc5\x99\xc3\xa1k'

# %%
from sim20q import Sim20q

# %%
x = Sim20q()
# Out:
# loading model
# construct meta info for corpus

# %%
x.lookup
# Out:
# {u'Types': {u'american_football.football_coach': {u'm.0g1dt1', u'm.0py2_dp'},
#   u'american_football.football_player': {u'm.0g1dt1'},
#   u'architecture.architectural_structure_owner': {u'm.03d6q'},
#   u'award.award_nominee': {u'm.015882',
#    u'm.015xp4',
#    u'm.017kq',
#    u'm.018gqj',
#    u'm.01bpc9',
#    u'm.01cbt3',
#    u'm.01dhy0',
#    u'm.01mkn_d',
#    u'm.01mpq7s',
#    u'm.01q810',
#    u'm.01s7mt3',
#    u'm.01vw37m',
#    u'm.020n_5',
#    u'm.021ch2',
#    u'm.02jxmr',
#    u'm.030myz',
#    u'm.038zc',
#    u'm.0478__m',
#    u'm.04ls53',
#    u'm.05h50h',
#    u'm.05xcm7',
#    u'm.072twv',
#    u'm.07d3x',
#    u'm.07q1v4',
#    u'm.07qy0b',
#    u'm.0d64fn',
#    u'm.0g824',
#    u'm.0x3b7'},
#   u'award.award_winner': {u'm.012hz4',
#    u'm.0134c8',
#    u'm.015882',
#    u'm.015xp4',
#    u'm.017kq',
#    u'm.018gqj',
#    u'm.01bpc9',
#    u'm.01cbt3',
#    u'm.01dhy0',
#    u'm.01mkn_d',
#    u'm.01mpq7s',
#    u'm.01s7mt3',
#    u'm.01vtg4q',
#    u'm.01vw37m',
#    u'm.020n_5',
#    u'm.021ch2',
#    u'm.02jxmr',
#    u'm.030myz',
#    u'm.038zc',
#    u'm.0478__m',
#    u'm.04ls53',
#    u'm.04w64q',
#    u'm.05h50h',
#    u'm.05vlhyt',
#    u'm.05xcm7',
#    u'm.072twv',
#    u'm.07d3x',
#    u'm.07q1v4',
#    u'm.0g824',
#    u'm.0x3b7'},
#   u'award.hall_of_fame_inductee': {u'm.0134c8',
#    u'm.015882',
#    u'm.015xp4',
#    u'm.01s7mt3',
#    u'm.01vtg4q'},
#   u'award.long_list_nominee': {u'm.07d3x'},
#   u'award.ranked_item': {u'm.01mpq7s', u'm.01vtg4q', u'm.0478__m', u'm.0g824'},
#   u'baseball.baseball_player': {u'm.02v1_j', u'm.0g05j8'},
#   u'book.author': {u'm.015882',
#    u'm.017kq',
#    u'm.018gqj',
#    u'm.01bpc9',
#    u'm.01gbpv',
#    u'm.01knhkl',
#    u'm.01q810',
#    u'm.021ch2',
#    u'm.02q4r',
#    u'm.03d6q',
#    u'm.05vh_gk',
#    u'm.05vlhyt',
#    u'm.05w_tlw',
#    u'm.05x68wv',
#    u'm.06_vvvp',
#    u'm.07d3x',
#    u'm.0bhqlny',
#    u'm.0c3q8tl',
#    u'm.0c5k2nx',
#    u'm.0d1sm',
#    u'm.0d3wx',
#    u'm.0g824',
#    u'm.0k59b'},
#   u'book.book_subject': {u'm.01dhy0', u'm.01gbpv', u'm.01mpq7s', u'm.021ch2'},
#   u'broadcast.artist': {u'm.012hz4',
#    u'm.0134c8',
#    u'm.015882',
#    u'm.015xp4',
#    u'm.018gqj',
#    u'm.01bpc9',
#    u'm.01cbt3',
#    u'm.01mpq7s',
#    u'm.01q810',
#    u'm.01s7mt3',
#    u'm.01vtg4q',
#    u'm.01vw37m',
#    u'm.01w1l3',
#    u'm.020n_5',
#    u'm.02jxmr',
#    u'm.030myz',
#    u'm.038zc',
#    u'm.03d6q',
#    u'm.0478__m',
#    u'm.0496_d',
#    u'm.07q1v4',
#    u'm.0d3wx',
#    u'm.0g824',
#    u'm.0k59b',
#    u'm.0x3b7'},
#   u'business.board_member': {u'm.03brys9', u'm.03d6q'},
#   u'business.product_endorser': {u'm.01mpq7s', u'm.01vw37m', u'm.0g824'},
#   u'celebrities.celebrity': {u'm.017kq',
#    u'm.01mpq7s',
#    u'm.0478__m',
#    u'm.0g824'},
#   u'common.webpage': {u'm.0d1sm', u'm.0k59b'},
#   u'cricket.cricket_player': {u'm.0h3lz86'},
#   u'fictional_universe.fictional_character_creator': {u'm.07d3x'},
#   u'fictional_universe.person_in_fiction': {u'm.015xp4',
#    u'm.02q4r',
#    u'm.03d6q'},
#   u'film.actor': {u'm.010p4n01',
#    u'm.012hz4',
#    u'm.0134c8',
#    u'm.015882',
#    u'm.015xp4',
#    u'm.017kq',
#    u'm.018gqj',
#    u'm.01bpc9',
#    u'm.01cbt3',
#    u'm.01dhy0',
#    u'm.01mkn_d',
#    u'm.01mpq7s',
#    u'm.01nb4p8',
#    u'm.01q810',
#    u'm.01vtg4q',
#    u'm.01vw37m',
#    u'm.01w1l3',
#    u'm.020n_5',
#    u'm.021ch2',
#    u'm.02jxmr',
#    u'm.02q4r',
#    u'm.030myz',
#    u'm.038zc',
#    u'm.0415hc',
#    u'm.0478__m',
#    u'm.04ls53',
#    u'm.05vlhyt',
#    u'm.05xcm7',
#    u'm.07q1v4',
#    u'm.09vxtvj',
#    u'm.0g1dt1',
#    u'm.0g824',
#    u'm.0nz1pby',
#    u'm.0w1qk__',
#    u'm.0x3b7'},
#   u'film.cinematographer': {u'm.0415hc', u'm.07qy0b'},
#   u'film.director': {u'm.01knhkl',
#    u'm.01mpq7s',
#    u'm.020n_5',
#    u'm.0415hc',
#    u'm.0478__m',
#    u'm.072twv',
#    u'm.09vxtvj',
#    u'm.0ck7rgl',
#    u'm.0d64fn',
#    u'm.0g824'},
#   u'film.editor': {u'm.020n_5', u'm.072twv'},
#   u'film.film_art_director': {u'm.072twv'},
#   u'film.film_crewmember': {u'm.072twv', u'm.0zm7rd0'},
#   u'film.film_production_designer': {u'm.072twv'},
#   u'film.film_set_designer': {u'm.072twv'},
#   u'film.film_story_contributor': {u'm.05vlhyt', u'm.07d3x'},
#   u'film.film_subject': {u'm.01dhy0',
#    u'm.01mpq7s',
#    u'm.03d6q',
#    u'm.0478__m',
#    u'm.07d3x'},
#   u'film.music_contributor': {u'm.015xp4',
#    u'm.017kq',
#    u'm.018gqj',
#    u'm.01bpc9',
#    u'm.01cbt3',
#    u'm.01gbpv',
#    u'm.01knhkl',
#    u'm.01mkn_d',
#    u'm.01nb4p8',
#    u'm.01w1l3',
#    u'm.020n_5',
#    u'm.02jxmr',
#    u'm.02q4r',
#    u'm.03d6q',
#    u'm.0496_d',
#    u'm.04ls53',
#    u'm.07q1v4',
#    u'm.07qy0b',
#    u'm.0ck7rgl',
#    u'm.0d1sm',
#    u'm.0k59b'},
#   u'film.person_or_entity_appearing_in_film': {u'm.012hz4',
#    u'm.015882',
#    u'm.017kq',
#    u'm.018gqj',
#    u'm.01bpc9',
#    u'm.01cbt3',
#    u'm.01dhy0',
#    u'm.01mpq7s',
#    u'm.01nb4p8',
#    u'm.01q810',
#    u'm.01s7mt3',
#    u'm.01vtg4q',
#    u'm.01vw37m',
#    u'm.020n_5',
#    u'm.021ch2',
#    u'm.02jxmr',
#    u'm.030myz',
#    u'm.038zc',
#    u'm.03d6q',
#    u'm.0478__m',
#    u'm.04ls53',
#    u'm.05h50h',
#    u'm.07d3x',
#    u'm.0g824',
#    u'm.0x3b7'},
#   u'film.producer': {u'm.017kq',
#    u'm.01mpq7s',
#    u'm.01vw37m',
#    u'm.020n_5',
#    u'm.0415hc',
#    u'm.0478__m',
#    u'm.0d64fn',
#    u'm.0g824'},
#   u'film.writer': {u'm.020n_5', u'm.05h50h', u'm.07d3x', u'm.0ck7rgl'},
#   u'government.politician': {u'm.02qs8s',
#    u'm.0hnb913',
#    u'm.0swmwbg',
#    u'm.0wyhd8q'},
#   u'influence.influence_node': {u'm.012hz4',
#    u'm.01gbpv',
#    u'm.01knhkl',
#    u'm.01mpq7s',
#    u'm.01s7mt3',
#    u'm.02q4r',
#    u'm.0478__m',
#    u'm.04ls53',
#    u'm.05xcm7',
#    u'm.07d3x',
#    u'm.07qy0b',
#    u'm.0d1sm',
#    u'm.0g824'},
#   u'internet.blogger': {u'm.0478__m'},
#   u'internet.social_network_user': {u'm.015882',
#    u'm.015xp4',
#    u'm.01bpc9',
#    u'm.01dhy0',
#    u'm.01mkn_d',
#    u'm.01mpq7s',
#    u'm.01q810',
#    u'm.01vtg4q',
#    u'm.01vw37m',
#    u'm.02jxmr',
#    u'm.030myz',
#    u'm.0478__m',
#    u'm.0g824',
#    u'm.0x3b7'},
#   u'media_common.dedicatee': {u'm.0d3wx'},
#   u'media_common.dedicator': {u'm.03d6q', u'm.0d1sm', u'm.0k59b'},
#   u'medicine.notable_person_with_medical_condition': {u'm.015882',
#    u'm.01mpq7s',
#    u'm.0478__m',
#    u'm.07d3x'},
#   u'music.artist': {u'm.012hz4',
#    u'm.0134c8',
#    u'm.015882',
#    u'm.015xp4',
#    u'm.017kq',
#    u'm.018gqj',
#    u'm.01bpc9',
#    u'm.01cbt3',
#    u'm.01dhy0',
#    u'm.01gbpv',
#    u'm.01knhkl',
#    u'm.01mkn_d',
#    u'm.01mpq7s',
#    u'm.01nb4p8',
#    u'm.01q810',
#    u'm.01s7mt3',
#    u'm.01smvx',
#    u'm.01v673k',
#    u'm.01vtg4q',
#    u'm.01vw37m',
#    u'm.01w1l3',
#    u'm.01w_61v',
#    u'm.020n_5',
#    u'm.021ch2',
#    u'm.02jxmr',
#    u'm.02q4r',
#    u'm.030myz',
#    u'm.038zc',
#    u'm.03d6q',
#    u'm.03f4tt8',
#    u'm.03j1zbt',
#    u'm.03j3lrv',
#    u'm.03xmsbw',
#    u'm.0478__m',
#    u'm.0496_d',
#    u'm.04ls53',
#    u'm.04w64q',
#    u'm.05h50h',
#    u'm.07q1v4',
#    u'm.07qy0b',
#    u'm.0d1sm',
#    u'm.0d3wx',
#    u'm.0dzc0gj',
#    u'm.0g824',
#    u'm.0k59b',
#    u'm.0x3b7',
#    u'm.0xd9qyq'},
#   u'music.composer': {u'm.0134c8',
#    u'm.015xp4',
#    u'm.017kq',
#    u'm.018gqj',
#    u'm.01bpc9',
#    u'm.01cbt3',
#    u'm.01gbpv',
#    u'm.01knhkl',
#    u'm.01mkn_d',
#    u'm.01mpq7s',
#    u'm.01nb4p8',
#    u'm.01q810',
#    u'm.01smvx',
#    u'm.01v673k',
#    u'm.01vtg4q',
#    u'm.01vw37m',
#    u'm.01w1l3',
#    u'm.020n_5',
#    u'm.02jxmr',
#    u'm.02q4r',
#    u'm.030myz',
#    u'm.03d6q',
#    u'm.0478__m',
#    u'm.0496_d',
#    u'm.04ls53',
#    u'm.05h50h',
#    u'm.07q1v4',
#    u'm.07qy0b',
#    u'm.0d1sm',
#    u'm.0d3wx',
#    u'm.0g824',
#    u'm.0k59b',
#    u'm.0x3b7'},
#   u'music.featured_artist': {u'm.015882',
#    u'm.01mpq7s',
#    u'm.01vw37m',
#    u'm.0478__m',
#    u'm.0g824',
#    u'm.0x3b7'},
#   u'music.group_member': {u'm.011jdvjl',
#    u'm.012hz4',
#    u'm.0134c8',
#    u'm.015882',
#    u'm.015xp4',
#    u'm.017kq',
#    u'm.018gqj',
#    u'm.01bpc9',
#    u'm.01cbt3',
#    u'm.01gbpv',
#    u'm.01knhkl',
#    u'm.01mkn_d',
#    u'm.01mpq7s',
#    u'm.01nb4p8',
#    u'm.01q810',
#    u'm.01s7mt3',
#    u'm.01smvx',
#    u'm.01v673k',
#    u'm.01vtg4q',
#    u'm.01vw37m',
#    u'm.01w1l3',
#    u'm.01w_61v',
#    u'm.020n_5',
#    u'm.021ch2',
#    u'm.02jxmr',
#    u'm.02q4r',
#    u'm.030myz',
#    u'm.038zc',
#    u'm.03d6q',
#    u'm.03f4tt8',
#    u'm.03xmsbw',
#    u'm.0478__m',
#    u'm.0496_d',
#    u'm.04ls53',
#    u'm.04w64q',
#    u'm.05h50h',
#    u'm.07q1v4',
#    u'm.07qy0b',
#    u'm.0d1sm',
#    u'm.0d3wx',
#    u'm.0dzc0gj',
#    u'm.0g824',
#    u'm.0g9n6v0',
#    u'm.0k59b',
#    u'm.0sl6c2d',
#    u'm.0x3b7'},
#   u'music.guitarist': {u'm.01bpc9', u'm.01vtg4q'},
#   u'music.lyricist': {u'm.0134c8',
#    u'm.015xp4',
#    u'm.017kq',
#    u'm.018gqj',
#    u'm.01bpc9',
#    u'm.01cbt3',
#    u'm.01gbpv',
#    u'm.01knhkl',
#    u'm.01mpq7s',
#    u'm.01q810',
#    u'm.01vtg4q',
#    u'm.01vw37m',
#    u'm.01w1l3',
#    u'm.020n_5',
#    u'm.02jxmr',
#    u'm.03d6q',
#    u'm.0478__m',
#    u'm.04ls53',
#    u'm.05h50h',
#    u'm.0d1sm',
#    u'm.0d3wx',
#    u'm.0g824',
#    u'm.0x3b7'},
#   u'music.music_video_director': {u'm.01mpq7s',
#    u'm.0415hc',
#    u'm.0478__m',
#    u'm.0g824'},
#   u'music.music_video_performer': {u'm.01vw37m', u'm.0478__m'},
#   u'music.musical_group': {u'm.01s7mt3'},
#   u'music.opera_singer': {u'm.015882'},
#   u'music.producer': {u'm.015882',
#    u'm.017kq',
#    u'm.018gqj',
#    u'm.01bpc9',
#    u'm.01cbt3',
#    u'm.01mpq7s',
#    u'm.01vw37m',
#    u'm.02jxmr',
#    u'm.0478__m',
#    u'm.0496_d',
#    u'm.04ls53',
#    u'm.05h50h',
#    u'm.07q1v4',
#    u'm.07qy0b',
#    u'm.0g824',
#    u'm.0x3b7'},
#   u'music.songwriter': {u'm.018gqj',
#    u'm.01cbt3',
#    u'm.01w1l3',
#    u'm.020n_5',
#    u'm.0x3b7'},
#   u'olympics.olympic_athlete': {u'm.043q705', u'm.04dzcy8'},
#   u'opera.librettist': {u'm.01knhkl', u'm.02q4r', u'm.0d1sm', u'm.0d3wx'},
#   u'organization.organization_founder': {u'm.017kq',
#    u'm.01bpc9',
#    u'm.01mpq7s',
#    u'm.01vw37m',
#    u'm.02q4r',
#    u'm.072twv',
#    u'm.0d1sm',
#    u'm.0g824'},
#   u'organization.organization_member': {u'm.021ch2'},
#   u'people.deceased_person': {u'm.012hz4',
#    u'm.0134c8',
#    u'm.015xp4',
#    u'm.01cbt3',
#    u'm.01dhy0',
#    u'm.01gbpv',
#    u'm.01knhkl',
#    u'm.01nb4p8',
#    u'm.01smvx',
#    u'm.01v673k',
#    u'm.01vtg4q',
#    u'm.01w1l3',
#    u'm.021ch2',
#    u'm.02q4r',
#    u'm.02qzjfk',
#    u'm.02r6sjg',
#    u'm.030myz',
#    u'm.03d6q',
#    u'm.0421rg8',
#    u'm.043q705',
#    u'm.0496_d',
#    u'm.04dzcy8',
#    u'm.05q8gg6',
#    u'm.06_vvvp',
#    u'm.072twv',
#    u'm.0d1sm',
#    u'm.0d3wx',
#    u'm.0g05j8',
#    u'm.0g1dt1',
#    u'm.0gx_cb7',
#    u'm.0k59b',
#    u'm.0swmwbg'},
#   u'people.measured_person': {u'm.01mpq7s',
#    u'm.02qzjfk',
#    u'm.02v1_j',
#    u'm.03hpdsv',
#    u'm.043q705',
#    u'm.04dzcy8',
#    u'm.09g91q4',
#    u'm.0chk5v',
#    u'm.0g05j8',
#    u'm.0g1dt1',
#    u'm.0g824',
#    u'm.0h3lz86',
#    u'm.0vxg911',
#    u'm.0wgpp9_'},
#   u'people.person': {u'm.010p4n01',
#    u'm.01160bvd',
#    u'm.011jdvjl',
#    u'm.012hz4',
#    u'm.0134c8',
#    u'm.015882',
#    u'm.015xp4',
#    u'm.017kq',
#    u'm.018gqj',
#    u'm.01bpc9',
#    u'm.01cbt3',
#    u'm.01dhy0',
#    u'm.01gbpv',
#    u'm.01knhkl',
#    u'm.01mkn_d',
#    u'm.01mpq7s',
#    u'm.01nb4p8',
#    u'm.01q810',
#    u'm.01s7mt3',
#    u'm.01smvx',
#    u'm.01v673k',
#    u'm.01vtg4q',
#    u'm.01vw37m',
#    u'm.01w1l3',
#    u'm.01w_61v',
#    u'm.020n_5',
#    u'm.021ch2',
#    u'm.02jxmr',
#    u'm.02q4r',
#    u'm.02qs8s',
#    u'm.02qzjfk',
#    u'm.02r6sjg',
#    u'm.02v1_j',
#    u'm.030myz',
#    u'm.038zc',
#    u'm.03brys9',
#    u'm.03d6q',
#    u'm.03f4tt8',
#    u'm.03hpdsv',
#    u'm.03j1zbt',
#    u'm.03j3lrv',
#    u'm.03xmsbw',
#    u'm.0415hc',
#    u'm.0421rg8',
#    u'm.043q705',
#    u'm.0472pg',
#    u'm.0478__m',
#    u'm.0496_d',
#    u'm.04dzcy8',
#    u'm.04ls53',
#    u'm.04w64q',
#    u'm.05h50h',
#    u'm.05q8gg6',
#    u'm.05vh_gk',
#    u'm.05vlhyt',
#    u'm.05w_tlw',
#    u'm.05x68wv',
#    u'm.05xcm7',
#    u'm.06_vvvp',
#    u'm.072twv',
#    u'm.07d3x',
#    u'm.07q1v4',
#    u'm.07qy0b',
#    u'm.080cdng',
#    u'm.09g91q4',
#    u'm.09vxtvj',
#    u'm.0bhqlny',
#    u'm.0c3q8tl',
#    u'm.0c5k2nx',
#    u'm.0chk5v',
#    u'm.0ck7rgl',
#    u'm.0d1sm',
#    u'm.0d3wx',
#    u'm.0d64fn',
#    u'm.0dzc0gj',
#    u'm.0g05j8',
#    u'm.0g1dt1',
#    u'm.0g824',
#    u'm.0g9n6v0',
#    u'm.0gx_cb7',
#    u'm.0gy5zqp',
#    u'm.0h3lz86',
#    u'm.0hnb913',
#    u'm.0hztzp9',
#    u'm.0j67j5s',
#    u'm.0k59b',
#    u'm.0nz1pby',
#    u'm.0py2_dp',
#    u'm.0sl6c2d',
#    u'm.0swmwbg',
#    u'm.0vxg911',
#    u'm.0w1qk__',
#    u'm.0w9vrgm',
#    u'm.0wd__t7',
#    u'm.0wgpp9_',
#    u'm.0wyhd8q',
#    u'm.0x3b7',
#    u'm.0xd9qyq',
#    u'm.0zfg717',
#    u'm.0zm7rd0'},
#   u'royalty.chivalric_order_member': {u'm.01dhy0',
#    u'm.021ch2',
#    u'm.02r6sjg',
#    u'm.03d6q'},
#   u'soccer.football_player': {u'm.02qzjfk',
#    u'm.03hpdsv',
#    u'm.09g91q4',
#    u'm.0chk5v'},
#   u'sports.pro_athlete': {u'm.02qzjfk',
#    u'm.02v1_j',
#    u'm.03hpdsv',
#    u'm.043q705',
#    u'm.04dzcy8',
#    u'm.09g91q4',
#    u'm.0chk5v',
#    u'm.0g05j8',
#    u'm.0g1dt1',
#    u'm.0h3lz86',
#    u'm.0vxg911',
#    u'm.0wgpp9_'},
#   u'sports.sports_award_winner': {u'm.02v1_j'},
#   u'sports.sports_team_coach': {u'm.0py2_dp'},
#   u'symbols.name_source': {u'm.01mpq7s', u'm.03d6q', u'm.0d1sm'},
#   u'symbols.namesake': {u'm.0478__m'},
#   u'theater.theater_actor': {u'm.015882', u'm.01bpc9'},
#   u'theater.theater_producer': {u'm.017kq', u'm.0g824'},
#   u'theater.theatrical_composer': {u'm.017kq',
#    u'm.018gqj',
#    u'm.02q4r',
#    u'm.03d6q',
#    u'm.0d1sm'},
#   u'theater.theatrical_lyricist': {u'm.017kq', u'm.018gqj'},
#   u'theater.theatrical_orchestrator': {u'm.017kq'},
#   u'tv.tv_actor': {u'm.0134c8',
#    u'm.015882',
#    u'm.015xp4',
#    u'm.018gqj',
#    u'm.01bpc9',
#    u'm.01cbt3',
#    u'm.01mpq7s',
#    u'm.01vtg4q',
#    u'm.01vw37m',
#    u'm.030myz',
#    u'm.038zc',
#    u'm.0478__m',
#    u'm.0496_d',
#    u'm.05xcm7',
#    u'm.07d3x',
#    u'm.07q1v4',
#    u'm.0g824',
#    u'm.0x3b7'},
#   u'tv.tv_personality': {u'm.018gqj',
#    u'm.01mpq7s',
#    u'm.01vtg4q',
#    u'm.01vw37m',
#    u'm.020n_5',
#    u'm.0478__m',
#    u'm.07d3x',
#    u'm.0g824'},
#   u'tv.tv_producer': {u'm.01vw37m'},
#   u'tv.tv_program_creator': {u'm.020n_5',
#    u'm.0478__m',
#    u'm.07d3x',
#    u'm.0zfg717'},
#   u'tv.tv_program_guest': {u'm.015882', u'm.01mpq7s', u'm.0478__m'},
#   u'tv.tv_writer': {u'm.07d3x', u'm.0zfg717'},
#   u'user.alexbl.honorary_title.titled_person': {u'm.021ch2', u'm.02r6sjg'},
#   u'user.alexbl.honorary_title.topic': {u'm.021ch2'},
#   u'user.alust.default_domain.processed_with_review_queue': {u'm.017kq',
#    u'm.018gqj',
#    u'm.01q810',
#    u'm.01vtg4q',
#    u'm.05vlhyt',
#    u'm.05xcm7',
#    u'm.0d3wx',
#    u'm.0k59b'},
#   u'user.maxim75.default_domain.dbpedia_import': {u'm.0415hc'},
#   u'user.narphorium.people.nndb_person': {u'm.0134c8',
#    u'm.015882',
#    u'm.015xp4',
#    u'm.018gqj',
#    u'm.01knhkl',
#    u'm.01q810',
#    u'm.01vtg4q',
#    u'm.01vw37m',
#    u'm.020n_5',
#    u'm.02q4r',
#    u'm.030myz',
#    u'm.038zc',
#    u'm.03d6q',
#    u'm.07d3x',
#    u'm.0d3wx',
#    u'm.0g824',
#    u'm.0k59b',
#    u'm.0x3b7'},
#   u'user.narphorium.people.topic': {u'm.0134c8',
#    u'm.015882',
#    u'm.015xp4',
#    u'm.018gqj',
#    u'm.01knhkl',
#    u'm.01q810',
#    u'm.01vtg4q',
#    u'm.01vw37m',
#    u'm.020n_5',
#    u'm.02q4r',
#    u'm.030myz',
#    u'm.038zc',
#    u'm.03d6q',
#    u'm.07d3x',
#    u'm.0d3wx',
#    u'm.0g824',
#    u'm.0k59b',
#    u'm.0x3b7'},
#   u'user.ngerakines.social_software.twitter_user': {u'm.0478__m'},
#   u'user.robert.default_domain.famous_czech': {u'm.0k59b'},
#   u'user.robert.performance.performer': {u'm.01q810'},
#   u'user.viral.default_domain.music_publisher': {u'm.015882'},
#   u'user.wf.shape_note_singing.singer': {u'm.015xp4',
#    u'm.0478__m',
#    u'm.0g824'},
#   u'user.xena.default_domain.contralto': {u'm.015xp4',
#    u'm.0478__m',
#    u'm.0g824'},
#   u'user.xena.default_domain.soprano': {u'm.0x3b7'},
#   u'visual_art.visual_artist': {u'm.0d3wx', u'm.0d64fn'}},
#  u'birthday': {u'760': {u'm.0421rg8'},
#   u'767-06-19': {u'm.02r6sjg'},
#   u'812-01-11': {u'm.0gx_cb7'},
#   u'813-10-10': {u'm.03d6q'},
#   u'835-10-09': {u'm.0d1sm'},
#   u'841-09-08': {u'm.0k59b'},
#   u'858-01-17': {u'm.06_vvvp'},
#   u'866-05-17': {u'm.02q4r'},
#   u'872-01-06': {u'm.01gbpv'},
#   u'874-09-21': {u'm.0d3wx'},
#   u'877-01-22': {u'm.0g05j8'},
#   u'887-09-23': {u'm.04dzcy8'},
#   u'893-03-23': {u'm.072twv'},
#   u'911-09-24': {u'm.02qzjfk'},
#   u'911-12-15': {u'm.030myz'},
#   u'912-09-27': {u'm.0g1dt1'},
#   u'913': {u'm.05vh_gk'},
#   u'914-07-11': {u'm.01nb4p8'},
#   u'915-12-09': {u'm.021ch2'},
#   u'921-10-22': {u'm.01w1l3'},
#   u'924-11-12': {u'm.01v673k'},
#   u'925-03-04': {u'm.0496_d'},
#   u'928-05-12': {u'm.018gqj'},
#   u'928-08-22': {u'm.01knhkl'},
#   u'928-12-30': {u'm.01vtg4q'},
#   u'931-07-21': {u'm.01smvx'},
#   u'933-01-17': {u'm.012hz4'},
#   u'933-11-03': {u'm.01cbt3'},
#   u'934-06-09': {u'm.0134c8'},
#   u'938-01-06': {u'm.020n_5'},
#   u'938-01-25': {u'm.015xp4'},
#   u'939-04-09': {u'm.043q705'},
#   u'941': {u'm.05vlhyt'},
#   u'941-11-21': {u'm.04w64q'},
#   u'944-08-18': {u'm.0472pg'},
#   u'945-01-26': {u'm.01dhy0'},
#   u'945-04-25': {u'm.017kq'},
#   u'946-05-17': {u'm.05h50h'},
#   u'946-07-15': {u'm.015882'},
#   u'947-04-02': {u'm.0x3b7'},
#   u'948-04-28': {u'm.07d3x'},
#   u'949-09-07': {u'm.038zc'},
#   u'951-06-09': {u'm.02jxmr'},
#   u'951-09-07': {u'm.07q1v4'},
#   u'954': {u'm.0c3q8tl'},
#   u'954-03-11': {u'm.07qy0b'},
#   u'955-01-17': {u'm.01bpc9'},
#   u'956-08-18': {u'm.01mkn_d'},
#   u'957-07-09': {u'm.01q810'},
#   u'958-05-01': {u'm.0h3lz86'},
#   u'961': {u'm.0hnb913'},
#   u'961-03-05': {u'm.0chk5v'},
#   u'962-07-29': {u'm.03hpdsv'},
#   u'962-11-01': {u'm.0wyhd8q'},
#   u'964-11-10': {u'm.02v1_j'},
#   u'967-10-10': {u'm.04ls53'},
#   u'970': {u'm.0d64fn'},
#   u'970-11-08': {u'm.05xcm7'},
#   u'973-04-03': {u'm.0py2_dp'},
#   u'977-09-11': {u'm.01vw37m'},
#   u'981-01-25': {u'm.0g824'},
#   u'981-09-04': {u'm.01mpq7s'},
#   u'982-08-31': {u'm.09g91q4'},
#   u'986-03-28': {u'm.0478__m'},
#   u'991-12-15': {u'm.0vxg911'},
#   u'992': {u'm.0wgpp9_'}},
#  u'birthplace': {u'Airdrie': {u'm.02qzjfk'},
#   u'Ankara': {u'm.04w64q'},
#   u'Aylesbury': {u'm.0vxg911'},
#   u'Beaconsfield': {u'm.07d3x'},
#   u'Berkeley': {u'm.043q705'},
#   u'Birmingham': {u'm.03hpdsv', u'm.0x3b7'},
#   u'Buenos Aires': {u'm.01nb4p8'},
#   u'Champaign': {u'm.01vw37m'},
#   u'Cheltenham': {u'm.0d3wx'},
#   u'Detroit': {u'm.0134c8'},
#   u'Dublin': {u'm.072twv'},
#   u'Fort Monroe': {u'm.01bpc9'},
#   u'Glendale': {u'm.01mkn_d'},
#   u'Gothenburg': {u'm.017kq'},
#   u'Greco': {u'm.020n_5'},
#   u'Gronau': {u'm.05h50h'},
#   u'Hammersmith': {u'm.0chk5v'},
#   u"Hell's Kitchen": {u'm.0g824'},
#   u'Herminie': {u'm.01smvx'},
#   u'Hetton-le-Hole': {u'm.0h3lz86'},
#   u'Honesdale': {u'm.0g05j8'},
#   u'Honfleur': {u'm.02q4r'},
#   u'Houston': {u'm.01mpq7s'},
#   u'Jacksonville': {u'm.01v673k'},
#   u'Jarocin': {u'm.021ch2'},
#   u'Kansas City': {u'm.018gqj'},
#   u'Le Roncole': {u'm.03d6q'},
#   u'Los Angeles': {u'm.015xp4', u'm.02jxmr', u'm.07qy0b'},
#   u'Marseille': {u'm.0496_d'},
#   u'McComb': {u'm.01vtg4q'},
#   u'Moscow': {u'm.01gbpv'},
#   u'M\xf6drath': {u'm.01knhkl'},
#   u'Nelahozeves': {u'm.0k59b'},
#   u'New Orleans': {u'm.0wyhd8q'},
#   u'New York City': {u'm.0478__m', u'm.07q1v4'},
#   u'Newark': {u'm.038zc'},
#   u'Ottawa': {u'm.05xcm7'},
#   u'Oxford': {u'm.01dhy0'},
#   u'Paris': {u'm.0d1sm'},
#   u'Philadelphia': {u'm.0py2_dp'},
#   u'Riverside': {u'm.04ls53'},
#   u'Runcorn': {u'm.0d64fn'},
#   u'San Francisco': {u'm.05vlhyt'},
#   u'Santa Cruz de Tenerife': {u'm.09g91q4'},
#   u'Savannah': {u'm.02v1_j'},
#   u'Shubra': {u'm.012hz4'},
#   u'Southport': {u'm.01q810'},
#   u'Staten Island': {u'm.0g1dt1'},
#   u'S\xe8te': {u'm.01w1l3'},
#   u'Tucson': {u'm.015882'},
#   u'Wichita': {u'm.030myz'},
#   u'Winnipeg': {u'm.0472pg'},
#   u'York': {u'm.01cbt3'}},
#  u'deathplace': {u'Algiers': {u'm.0d1sm'},
#   u'Archer': {u'm.01vtg4q'},
#   u'Arcueil': {u'm.02q4r'},
#   u'Buenos Aires': {u'm.01nb4p8'},
#   u'Cincinnati': {u'm.0g1dt1'},
#   u'Danville': {u'm.0g05j8'},
#   u'Hollywood': {u'm.072twv'},
#   u'K\xfcrten': {u'm.01knhkl'},
#   u'London': {u'm.01dhy0', u'm.0d3wx'},
#   u'Los Angeles': {u'm.030myz'},
#   u'Milan': {u'm.03d6q'},
#   u'Moscow': {u'm.01gbpv'},
#   u'Mount Holly': {u'm.0134c8'},
#   u'New York City': {u'm.01smvx', u'm.01v673k'},
#   u'Paris': {u'm.012hz4'},
#   u'Perpignan': {u'm.0496_d'},
#   u'Prague': {u'm.0k59b'},
#   u'Riverside': {u'm.015xp4'},
#   u'Saint-G\xe9ly-du-Fesc': {u'm.01w1l3'},
#   u'Schruns': {u'm.021ch2'},
#   u'Town of Oyster Bay': {u'm.01cbt3'}},
#  u'degree': {},
#  u'education': {u'Alief Elsik High School': {u'm.01mpq7s'},
#   u'Arizona State University': {u'm.015882'},
#   u'Art Students League of New York': {u'm.072twv'},
#   u'Banneker High School': {u'm.01vw37m'},
#   u'Bell High School': {u'm.030myz'},
#   u'Berlin University of the Arts': {u'm.021ch2'},
#   u'California Institute of the Arts': {u'm.01mkn_d'},
#   u'Columbia University': {u'm.0g824'},
#   u'Conservatoire de Paris': {u'm.02q4r',
#    u'm.0496_d',
#    u'm.04w64q',
#    u'm.0d1sm'},
#   u'Convent of the Sacred Heart': {u'm.0478__m'},
#   u'Gar-Field Senior High School': {u'm.0x3b7'},
#   u'Georgia State University': {u'm.01vw37m'},
#   u'Guildhall School of Music and Drama': {u'm.01dhy0'},
#   u'Hertford College, Oxford': {u'm.0hnb913'},
#   u'High School for the Performing and Visual Arts': {u'm.01mpq7s'},
#   u'Hochschule f\xfcr Musik und Tanz K\xf6ln': {u'm.01knhkl'},
#   u'Jesus College, Oxford': {u'm.0421rg8', u'm.05q8gg6'},
#   u'John Hampden Grammar School': {u'm.07d3x'},
#   u'Juilliard School': {u'm.04ls53'},
#   u'Leeds Beckett University': {u'm.01q810'},
#   u'Lund University': {u'm.017kq'},
#   u'Mannes College The New School for Music': {u'm.018gqj'},
#   u'McGill University': {u'm.018gqj'},
#   u'Moscow Conservatory': {u'm.01gbpv'},
#   u'Music Academy of the West': {u'm.02jxmr'},
#   u'Oak Park and River Forest High School': {u'm.01vw37m'},
#   u'Parker Elementary School': {u'm.01mpq7s'},
#   u"Pate's Grammar School": {u'm.0d3wx'},
#   u'Professional Performing Arts School': {u'm.0g824'},
#   u'Royal College of Music': {u'm.0d3wx'},
#   u'Schola Cantorum de Paris': {u'm.02q4r'},
#   u'School of Visual Arts': {u'm.04ls53'},
#   u'Scuola Tecnica Commerciale Maria Ausiliatrice': {u'm.012hz4'},
#   u"St Peter's School, York": {u'm.01cbt3'},
#   u"St. Mary's Elementary School": {u'm.01mpq7s'},
#   u'The Thacher School': {u'm.02jxmr'},
#   u'Tisch School of the Arts': {u'm.0478__m'},
#   u'Ulster University': {u'm.0d64fn'},
#   u'University College London': {u'm.0d3wx'},
#   u'University of Bonn': {u'm.01knhkl'},
#   u'University of Manchester': {u'm.0d64fn'},
#   u'University of North Carolina at Greensboro': {u'm.0x3b7'},
#   u'University of Notre Dame': {u'm.0g1dt1'},
#   u'University of Southern California': {u'm.02jxmr', u'm.07qy0b'}},
#  u'gender': {u'Female': {u'm.012hz4',
#    u'm.015882',
#    u'm.015xp4',
#    u'm.01dhy0',
#    u'm.01mpq7s',
#    u'm.021ch2',
#    u'm.038zc',
#    u'm.0478__m',
#    u'm.04w64q',
#    u'm.0g824',
#    u'm.0gy5zqp',
#    u'm.0x3b7'},
#   u'Male': {u'm.010p4n01',
#    u'm.01160bvd',
#    u'm.011jdvjl',
#    u'm.0134c8',
#    u'm.017kq',
#    u'm.018gqj',
#    u'm.01bpc9',
#    u'm.01cbt3',
#    u'm.01gbpv',
#    u'm.01knhkl',
#    u'm.01mkn_d',
#    u'm.01nb4p8',
#    u'm.01q810',
#    u'm.01smvx',
#    u'm.01v673k',
#    u'm.01vtg4q',
#    u'm.01vw37m',
#    u'm.01w1l3',
#    u'm.01w_61v',
#    u'm.020n_5',
#    u'm.02jxmr',
#    u'm.02q4r',
#    u'm.02qs8s',
#    u'm.02qzjfk',
#    u'm.02r6sjg',
#    u'm.02v1_j',
#    u'm.030myz',
#    u'm.03d6q',
#    u'm.03hpdsv',
#    u'm.03xmsbw',
#    u'm.0415hc',
#    u'm.0421rg8',
#    u'm.043q705',
#    u'm.0472pg',
#    u'm.0496_d',
#    u'm.04dzcy8',
#    u'm.04ls53',
#    u'm.05h50h',
#    u'm.05q8gg6',
#    u'm.05vlhyt',
#    u'm.05xcm7',
#    u'm.072twv',
#    u'm.07d3x',
#    u'm.07q1v4',
#    u'm.07qy0b',
#    u'm.080cdng',
#    u'm.09vxtvj',
#    u'm.0chk5v',
#    u'm.0ck7rgl',
#    u'm.0d1sm',
#    u'm.0d3wx',
#    u'm.0d64fn',
#    u'm.0g05j8',
#    u'm.0g1dt1',
#    u'm.0gx_cb7',
#    u'm.0h3lz86',
#    u'm.0hztzp9',
#    u'm.0k59b',
#    u'm.0nz1pby',
#    u'm.0py2_dp',
#    u'm.0swmwbg',
#    u'm.0vxg911',
#    u'm.0w1qk__',
#    u'm.0w9vrgm',
#    u'm.0wgpp9_',
#    u'm.0wyhd8q'}},
#  u'name': {u'"Adriano Celentano"@en': {u'm.020n_5'},
#   u'"Alexander Scriabin"@en': {u'm.01gbpv'},
#   u'"Alicia Keys"@en': {u'm.0g824'},
#   u'"Andy Williams"@en': {u'm.03hpdsv'},
#   u'"Anne Murray"@en': {u'm.05w_tlw'},
#   u'"Anton\xedn Dvo\u0159\xe1k"@en': {u'm.0k59b'},
#   u'"An\xedbal Troilo"@en': {u'm.01nb4p8'},
#   u'"Barbara"@en': {u'm.0xd9qyq'},
#   u'"Beyonc\xe9 Knowles"@en': {u'm.01mpq7s'},
#   u'"Bill Nelson"@en': {u'm.03brys9'},
#   u'"Bj\xf6rn Ulvaeus"@en': {u'm.017kq'},
#   u'"Bo Diddley"@en': {u'm.01vtg4q'},
#   u'"Bryan Adams"@en': {u'm.0wyhd8q'},
#   u'"Bryn Jones"@en': {u'm.03f4tt8'},
#   u'"Burt Bacharach"@en': {u'm.018gqj'},
#   u'"Camille Saint-Sa\xebns"@en': {u'm.0d1sm'},
#   u'"Cedric Gibbons"@en': {u'm.072twv'},
#   u'"Chris Brown"@en': {u'm.0gy5zqp', u'm.0wgpp9_', u'm.0zm7rd0'},
#   u'"Colin Davis"@en': {u'm.0nz1pby'},
#   u'"Dalida"@en': {u'm.012hz4'},
#   u'"David Byrne"@en': {u'm.0chk5v'},
#   u'"David Newman"@en': {u'm.0472pg', u'm.07qy0b', u'm.0hnb913'},
#   u'"Elisabeth Schwarzkopf"@en': {u'm.021ch2'},
#   u'"Emmylou Harris"@en': {u'm.0x3b7'},
#   u'"Eric Burdon & the Animals"@en': {u'm.01s7mt3'},
#   u'"Erik Satie"@en': {u'm.02q4r'},
#   u'"Etta James"@en': {u'm.015xp4'},
#   u'"George Harrison"@en': {u'm.02r6sjg', u'm.043q705'},
#   u'"Georges Brassens"@en': {u'm.01w1l3'},
#   u'"Giuseppe Verdi"@en': {u'm.03d6q'},
#   u'"Gloria Gaynor"@en': {u'm.038zc'},
#   u'"Graham Johnson"@en': {u'm.0h3lz86'},
#   u'"Gustav Holst"@en': {u'm.0d3wx'},
#   u'"Jackie Wilson"@en': {u'm.0134c8'},
#   u'"Jacqueline du Pr\xe9"@en': {u'm.01dhy0'},
#   u'"James Brown"@en': {u'm.0dzc0gj', u'm.0gx_cb7'},
#   u'"James Last"@en': {u'm.011jdvjl'},
#   u'"James Newton Howard"@en': {u'm.02jxmr'},
#   u'"James Taylor"@en': {u'm.0sl6c2d'},
#   u'"Jimmy Smith"@en': {u'm.02qzjfk'},
#   u'"Joan Baez"@en': {u'm.05vh_gk'},
#   u'"John Barry"@en': {u'm.01cbt3'},
#   u'"John Butler"@en': {u'm.0j67j5s', u'm.0py2_dp', u'm.0w9vrgm'},
#   u'"John Debney"@en': {u'm.01mkn_d'},
#   u'"John Lewis"@en': {u'm.05x68wv', u'm.06_vvvp', u'm.0zfg717'},
#   u'"John Powell"@en': {u'm.01160bvd', u'm.0c3q8tl', u'm.0wd__t7'},
#   u'"John Williams"@en': {u'm.0421rg8',
#    u'm.05q8gg6',
#    u'm.0c5k2nx',
#    u'm.0ck7rgl',
#    u'm.0hztzp9'},
#   u'"Karl Richter"@en': {u'm.04dzcy8'},
#   u'"Karlheinz Stockhausen"@en': {u'm.01knhkl'},
#   u'"Kenny Rogers"@en': {u'm.02v1_j'},
#   u'"Lady Gaga"@en': {u'm.0478__m'},
#   u'"Linda Ronstadt"@en': {u'm.015882'},
#   u'"Ludacris"@en': {u'm.01vw37m'},
#   u'"Marc Almond"@en': {u'm.01q810'},
#   u'"Mark Isham"@en': {u'm.07q1v4'},
#   u'"Michael Giacchino"@en': {u'm.04ls53'},
#   u'"Michael Jackson"@en': {u'm.02qs8s', u'm.05xcm7'},
#   u'"Miles Davis"@en': {u'm.010p4n01'},
#   u'"Mina"@en': {u'm.03j3lrv'},
#   u'"Patrick Doyle"@en': {u'm.0swmwbg'},
#   u'"Paul Mauriat"@en': {u'm.0496_d'},
#   u'"Phil Collins"@en': {u'm.0d64fn'},
#   u'"Richard Thompson"@en': {u'm.0bhqlny', u'm.0w1qk__'},
#   u'"Ricky Nelson"@en': {u'm.01w_61v'},
#   u'"Robert Johnson"@en': {u'm.0g9n6v0'},
#   u'"Roberto Carlos"@en': {u'm.09g91q4'},
#   u'"Ron Jones"@en': {u'm.05vlhyt'},
#   u'"Sam Jones"@en': {u'm.01v673k', u'm.0415hc', u'm.0vxg911'},
#   u'"Scott Ross"@en': {u'm.080cdng'},
#   u'"Sonny Clark"@en': {u'm.01smvx'},
#   u'"Stan Kenton"@en': {u'm.030myz'},
#   u'"Steve Earle"@en': {u'm.01bpc9'},
#   u'"Terry Pratchett"@en': {u'm.07d3x'},
#   u'"Tom Jones"@en': {u'm.03xmsbw', u'm.0g05j8'},
#   u'"Tony Williams"@en': {u'm.09vxtvj'},
#   u'"Udo Lindenberg"@en': {u'm.05h50h'},
#   u'"Viola"@en': {u'm.03j1zbt'},
#   u'"William Shakespeare"@en': {u'm.0g1dt1'},
#   u'"\u0130dil Biret"@en': {u'm.04w64q'}},
#  u'nationality': {u'Argentina': {u'm.01nb4p8'},
#   u'Canada': {u'm.05xcm7'},
#   u'England': {u'm.01q810',
#    u'm.03hpdsv',
#    u'm.0chk5v',
#    u'm.0d3wx',
#    u'm.0d64fn',
#    u'm.0h3lz86',
#    u'm.0vxg911'},
#   u'France': {u'm.012hz4', u'm.01w1l3', u'm.02q4r', u'm.0496_d', u'm.0d1sm'},
#   u'Germany': {u'm.01knhkl', u'm.05h50h'},
#   u'Italy': {u'm.012hz4', u'm.020n_5', u'm.04ls53'},
#   u'Kingdom of Bohemia': {u'm.0k59b'},
#   u'Kingdom of Italy': {u'm.03d6q'},
#   u'Poland': {u'm.021ch2'},
#   u'Republic of Ireland': {u'm.072twv', u'm.0swmwbg'},
#   u'Russia': {u'm.01gbpv'},
#   u'Scotland': {u'm.02qzjfk'},
#   u'Spain': {u'm.09g91q4'},
#   u'Sweden': {u'm.017kq'},
#   u'Turkey': {u'm.04w64q'},
#   u'United Kingdom': {u'm.01cbt3', u'm.01dhy0', u'm.07d3x'},
#   u'United States of America': {u'm.0134c8',
#    u'm.015882',
#    u'm.015xp4',
#    u'm.018gqj',
#    u'm.01bpc9',
#    u'm.01mkn_d',
#    u'm.01mpq7s',
#    u'm.01smvx',
#    u'm.01v673k',
#    u'm.01vtg4q',
#    u'm.01vw37m',
#    u'm.02jxmr',
#    u'm.02v1_j',
#    u'm.030myz',
#    u'm.038zc',
#    u'm.043q705',
#    u'm.0478__m',
#    u'm.04ls53',
#    u'm.05vlhyt',
#    u'm.072twv',
#    u'm.07q1v4',
#    u'm.07qy0b',
#    u'm.0g05j8',
#    u'm.0g1dt1',
#    u'm.0g824',
#    u'm.0py2_dp',
#    u'm.0wyhd8q',
#    u'm.0x3b7'}},
#  u'profession': {u'Actor': {u'm.010p4n01',
#    u'm.012hz4',
#    u'm.015882',
#    u'm.017kq',
#    u'm.018gqj',
#    u'm.01bpc9',
#    u'm.01mpq7s',
#    u'm.01nb4p8',
#    u'm.01vtg4q',
#    u'm.01vw37m',
#    u'm.020n_5',
#    u'm.038zc',
#    u'm.0478__m',
#    u'm.04ls53',
#    u'm.05h50h',
#    u'm.05vlhyt',
#    u'm.05xcm7',
#    u'm.0g824',
#    u'm.0nz1pby',
#    u'm.0w1qk__',
#    u'm.0x3b7'},
#   u'American Football coach': {u'm.0py2_dp'},
#   u'American football player': {u'm.0g1dt1'},
#   u'Athlete': {u'm.0vxg911'},
#   u'Author': {u'm.01bpc9', u'm.07d3x'},
#   u'Bandleader': {u'm.030myz', u'm.0x3b7'},
#   u'Baseball player': {u'm.02v1_j', u'm.0g05j8'},
#   u'Bassist': {u'm.01v673k'},
#   u'Businessperson': {u'm.01mpq7s', u'm.0478__m'},
#   u'Cellist': {u'm.01dhy0', u'm.01v673k'},
#   u'Comedian': {u'm.020n_5'},
#   u'Composer': {u'm.017kq',
#    u'm.018gqj',
#    u'm.01bpc9',
#    u'm.01cbt3',
#    u'm.01gbpv',
#    u'm.01knhkl',
#    u'm.01mkn_d',
#    u'm.01nb4p8',
#    u'm.01v673k',
#    u'm.02jxmr',
#    u'm.02q4r',
#    u'm.030myz',
#    u'm.03d6q',
#    u'm.0478__m',
#    u'm.0496_d',
#    u'm.04ls53',
#    u'm.05h50h',
#    u'm.07q1v4',
#    u'm.07qy0b',
#    u'm.0d1sm',
#    u'm.0d3wx',
#    u'm.0k59b',
#    u'm.0w9vrgm'},
#   u'Conductor': {u'm.018gqj',
#    u'm.01cbt3',
#    u'm.01mkn_d',
#    u'm.01nb4p8',
#    u'm.03d6q',
#    u'm.0496_d',
#    u'm.07qy0b',
#    u'm.0d1sm'},
#   u'Entrepreneur': {u'm.01vw37m'},
#   u'Fashion designer': {u'm.0478__m'},
#   u'Film Art Director': {u'm.072twv'},
#   u'Film Editor': {u'm.020n_5'},
#   u'Film Producer': {u'm.01mpq7s', u'm.01vw37m', u'm.0478__m'},
#   u'Film Score Composer': {u'm.017kq',
#    u'm.018gqj',
#    u'm.01cbt3',
#    u'm.01mkn_d',
#    u'm.01nb4p8',
#    u'm.01vtg4q',
#    u'm.020n_5',
#    u'm.02jxmr',
#    u'm.0478__m',
#    u'm.0496_d',
#    u'm.04ls53',
#    u'm.05h50h',
#    u'm.07q1v4',
#    u'm.07qy0b'},
#   u'Film director': {u'm.020n_5', u'm.0478__m', u'm.0ck7rgl', u'm.0d64fn'},
#   u'Firefighter': {u'm.0wyhd8q'},
#   u'Guitarist': {u'm.01bpc9', u'm.01vtg4q'},
#   u'Jazz Pianist': {u'm.01smvx', u'm.030myz'},
#   u'Lyricist': {u'm.017kq', u'm.01bpc9'},
#   u'Music Arranger': {u'm.018gqj', u'm.030myz'},
#   u'Music Video Director': {u'm.0415hc'},
#   u'Music artist': {u'm.01mpq7s', u'm.0478__m'},
#   u'Music pedagogue': {u'm.0d3wx'},
#   u'Musician': {u'm.011jdvjl',
#    u'm.0134c8',
#    u'm.015882',
#    u'm.015xp4',
#    u'm.017kq',
#    u'm.01bpc9',
#    u'm.01cbt3',
#    u'm.01dhy0',
#    u'm.01mpq7s',
#    u'm.01nb4p8',
#    u'm.01q810',
#    u'm.01vtg4q',
#    u'm.020n_5',
#    u'm.02jxmr',
#    u'm.038zc',
#    u'm.0496_d',
#    u'm.04ls53',
#    u'm.07q1v4',
#    u'm.0g824',
#    u'm.0x3b7'},
#   u'Novelist': {u'm.07d3x'},
#   u'Opera composer': {u'm.03d6q'},
#   u'Orchestrator': {u'm.017kq', u'm.04ls53', u'm.07qy0b'},
#   u'Organist': {u'm.0d1sm', u'm.0k59b'},
#   u'Painter': {u'm.05h50h'},
#   u'Philanthropist': {u'm.0478__m'},
#   u'Photographer': {u'm.0d64fn'},
#   u'Pianist': {u'm.018gqj',
#    u'm.01gbpv',
#    u'm.02q4r',
#    u'm.04w64q',
#    u'm.0d1sm',
#    u'm.0g824'},
#   u'Playwright': {u'm.01bpc9'},
#   u'Poet': {u'm.05vlhyt'},
#   u'Politician': {u'm.0swmwbg', u'm.0wyhd8q'},
#   u'Pornographic film actor': {u'm.09vxtvj'},
#   u'Presenter': {u'm.020n_5'},
#   u'Production designer': {u'm.072twv'},
#   u'Rapper': {u'm.01vw37m'},
#   u'Record producer': {u'm.015882',
#    u'm.017kq',
#    u'm.018gqj',
#    u'm.01bpc9',
#    u'm.01mpq7s',
#    u'm.02jxmr',
#    u'm.0478__m',
#    u'm.0g824'},
#   u'Rocket scientist': {u'm.0hztzp9'},
#   u'Salesman': {u'm.0wyhd8q'},
#   u'Screenwriter': {u'm.020n_5',
#    u'm.0478__m',
#    u'm.05h50h',
#    u'm.07d3x',
#    u'm.0ck7rgl',
#    u'm.0zfg717'},
#   u'Set Decorator': {u'm.072twv'},
#   u'Singer': {u'm.012hz4',
#    u'm.0134c8',
#    u'm.015882',
#    u'm.015xp4',
#    u'm.018gqj',
#    u'm.01mpq7s',
#    u'm.01q810',
#    u'm.01vtg4q',
#    u'm.01w1l3',
#    u'm.021ch2',
#    u'm.038zc',
#    u'm.05h50h'},
#   u'Singer-songwriter': {u'm.0134c8',
#    u'm.015xp4',
#    u'm.01bpc9',
#    u'm.01mpq7s',
#    u'm.01q810',
#    u'm.01vtg4q',
#    u'm.01w1l3',
#    u'm.020n_5',
#    u'm.038zc',
#    u'm.0478__m',
#    u'm.0g824',
#    u'm.0x3b7'},
#   u'Social activist': {u'm.0478__m'},
#   u'Songwriter': {u'm.015882',
#    u'm.017kq',
#    u'm.018gqj',
#    u'm.01mpq7s',
#    u'm.01vtg4q',
#    u'm.02jxmr',
#    u'm.0x3b7'},
#   u'Teacher': {u'm.05vlhyt'},
#   u'Television producer': {u'm.01mpq7s', u'm.0478__m'},
#   u'Theatrical producer': {u'm.017kq'},
#   u'Trumpeter': {u'm.07q1v4'},
#   u'Video Artist': {u'm.0d64fn'},
#   u'Violinist': {u'm.07qy0b'},
#   u'Voice acting': {u'm.01mpq7s'},
#   u'Writer': {u'm.01bpc9', u'm.05h50h', u'm.05vlhyt', u'm.07d3x'}},
#  u'spouse': {u'Adriano Celentano': {u'm.020n_5'},
#   u'Agnetha F\xe4ltskog': {u'm.017kq'},
#   u'Alicia Keys': {u'm.0g824'},
#   u'Allison Moorer': {u'm.01bpc9'},
#   u'Angie Dickinson': {u'm.018gqj'},
#   u'Anna \u010cerm\xe1kov\xe1': {u'm.0k59b'},
#   u'Anton\xedn Dvo\u0159\xe1k': {u'm.0k59b'},
#   u'An\xedbal Troilo': {u'm.01nb4p8'},
#   u'Artis Mills': {u'm.015xp4'},
#   u'Barbara Pickard': {u'm.01cbt3'},
#   u'Beyonc\xe9 Knowles': {u'm.01mpq7s'},
#   u'Bj\xf6rn Ulvaeus': {u'm.017kq'},
#   u'Bo Diddley': {u'm.01vtg4q'},
#   u'Bob Brown': {u'm.0gy5zqp'},
#   u'Brian Ahern': {u'm.0x3b7'},
#   u'Burt Bacharach': {u'm.018gqj'},
#   u'Camille Saint-Sa\xebns': {u'm.0d1sm'},
#   u'Carol-Ann Hunter': {u'm.01bpc9'},
#   u'Carole Bayer Sager': {u'm.018gqj'},
#   u'Cedric Gibbons': {u'm.072twv'},
#   u'Chris Brown': {u'm.0gy5zqp'},
#   u'Claudia Mori': {u'm.020n_5'},
#   u'Cynthia Dunn': {u'm.01bpc9'},
#   u'Dalida': {u'm.012hz4'},
#   u'Daniel Barenboim': {u'm.01dhy0'},
#   u'David Newman': {u'm.07qy0b'},
#   u'Deanna Jones': {u'm.05vlhyt'},
#   u'Deborah Sale Butler': {u'm.0w9vrgm'},
#   u'Dolores del R\xedo': {u'm.072twv'},
#   u'Donna Isham': {u'm.07q1v4'},
#   u'Doris Andreae': {u'm.01knhkl'},
#   u'Elisabeth Schwarzkopf': {u'm.021ch2'},
#   u'Emily Isobel Harrison': {u'm.0d3wx'},
#   u'Emmylou Harris': {u'm.0x3b7'},
#   u'Erik Satie': {u'm.02q4r'},
#   u'Ethel Smith': {u'm.01vtg4q'},
#   u'Etta James': {u'm.015xp4'},
#   u'Giuseppe Verdi': {u'm.03d6q'},
#   u'Giuseppina Strepponi': {u'm.03d6q'},
#   u'Gloria Gaynor': {u'm.038zc'},
#   u'Gustav Holst': {u'm.0d3wx'},
#   u'Hazel Brooks': {u'm.072twv'},
#   u'Ida Dudui Kalacci': {u'm.01nb4p8'},
#   u'Ir\xe8ne Mauriat': {u'm.0496_d'},
#   u'Jacqueline du Pr\xe9': {u'm.01dhy0'},
#   u'James Newton Howard': {u'm.02jxmr'},
#   u'Jane Birkin': {u'm.01cbt3'},
#   u'Jane Hansen': {u'm.018gqj'},
#   u'Jane Sidey': {u'm.01cbt3'},
#   u'Jay-Z': {u'm.01mpq7s'},
#   u'Jean Sobieski': {u'm.012hz4'},
#   u'John Barry': {u'm.01cbt3'},
#   u'John Butler': {u'm.0w9vrgm'},
#   u'Karlheinz Stockhausen': {u'm.01knhkl'},
#   u'Kay Reynolds': {u'm.01vtg4q'},
#   u'Krystyna Newman': {u'm.07qy0b'},
#   u'Laurie Barry': {u'm.01cbt3'},
#   u'Lena Kallersj\xf6': {u'm.017kq'},
#   u'Linwood Simon': {u'm.038zc'},
#   u'Lou-Anne Gill': {u'm.01bpc9'},
#   u'Louise Woolingham': {u'm.01vtg4q'},
#   u'Lucien Morisse': {u'm.012hz4'},
#   u'Lyn Pratchett': {u'm.07d3x'},
#   u'Margherita Barezzi': {u'm.03d6q'},
#   u'Maria Teresa Ensenat': {u'm.01bpc9'},
#   u'Marie Laure Emile Truffot': {u'm.0d1sm'},
#   u'Mark Isham': {u'm.07q1v4'},
#   u'Mary Bauermeister': {u'm.01knhkl'},
#   u'Paul Kennerley': {u'm.0x3b7'},
#   u'Paul Mauriat': {u'm.0496_d'},
#   u'Paula Stewart': {u'm.018gqj'},
#   u'Ron Jones': {u'm.05vlhyt'},
#   u'Rosanna Arquette': {u'm.02jxmr'},
#   u'Sandra Jean Henderson': {u'm.01bpc9'},
#   u'Sophie Howard': {u'm.02jxmr'},
#   u'Steve Earle': {u'm.01bpc9'},
#   u'Suzanne Valadon': {u'm.02q4r'},
#   u'Swizz Beatz': {u'm.0g824'},
#   u'Sylvia Paiz': {u'm.01vtg4q'},
#   u'Terry Pratchett': {u'm.07d3x'},
#   u'Tom Slocum': {u'm.0x3b7'},
#   u'Walter Legge': {u'm.021ch2'}}}
